# %%
# Count tracks & videos in excel files and supp. material
import os
from collections import defaultdict
from datetime import datetime
import time
import re
import sys
import pandas as pd
import logging
from PIL import Image

logging.basicConfig(
    level=logging.INFO,
    format="[%(asctime)s] %(message)s",
    datefmt='%d-%b-%y %H:%M:%S',
    handlers=[
        logging.FileHandler(fr'C:\Users\pc\Desktop\Doctorado\Publicaciones\Papers enucleadas\Tracks válidas\Track_info_{datetime.now().strftime("%d.%m.%Y_%H.%M.%S")}.txt'),
        logging.StreamHandler(sys.stdout)
    ]
)

t = time.time()

walk_dir = r'C:\Users\pc\Desktop\Doctorado\Publicaciones\Papers enucleadas\Tracks válidas'

logging.info('\n\n\nwalk_dir = ' + walk_dir)
# If your current working directory may change during script execution, it's recommended to
# immediately convert program arguments to an absolute path. Then the variable root below will
# be an absolute path as well.
walk_dir = os.path.abspath(walk_dir)
logging.info('walk_dir (absolute) = ' + os.path.abspath(walk_dir))

excelfiles = []
tracks_quantity = defaultdict()
numreps = defaultdict()
numcells = defaultdict(defaultdict().copy)
max_min_cells = defaultdict(defaultdict().copy)
left_n = defaultdict(defaultdict().copy)
right_n = defaultdict(defaultdict().copy)
x_displacement_serie = defaultdict(defaultdict().copy)

for root, subdirs, files in os.walk(walk_dir):
    logging.info(f'\nNOW IN ROOT = {root}\n')
    logging.info(f'\nThere are {len(files)} files in {root}')
    
    for subdir in subdirs:
        logging.info('\t- subdirectory ' + subdir)

    for filename in files:
        if filename.endswith('.xlsx'):
            excelfiles.append(filename)
            scenario = root.rsplit('\\',2)[1]
            cell_type = root.rsplit('\\',1)[1]
            experiment = scenario + '_' + cell_type
            file_path = os.path.join(root, filename)
            serie = pd.read_excel(file_path, header=None)
            #Coordenadas X iniciales de cada célula en esa serie
            o = serie.groupby(2, as_index=False).first()[4] 
            #Coordenadas X finales de cada célula en esa serie
            f = serie.groupby(2, as_index=False).last()[4]
            x_displacement_serie[experiment][filename] = [f_i-o_i for o_i,f_i in zip(o.tolist(), f.tolist())]
            if any(ele == 0 for ele in x_displacement_serie[experiment][filename]): # detect cells with no displacement
                logging.critical(f'\t- cell(s) nº {[idx for idx, val in enumerate(x_displacement_serie[experiment][filename]) if val == 0]} have no displacement')
                raise SystemExit(f'\t- cell(s) nº {[idx for idx, val in enumerate(x_displacement_serie[experiment][filename]) if val == 0]} have no displacement')
            left_n[experiment][filename] = sum(1 for value in x_displacement_serie[experiment][filename] if value < 0 )
            right_n[experiment][filename] = sum(1 for value in x_displacement_serie[experiment][filename] if value > 0 )
            numcells[experiment][filename] = len(x_displacement_serie[experiment][filename])
            logging.info(f'\n- video {filename} contains {numcells[experiment][filename]} tracks and {len(serie)} data points,{chr(10)}{chr(10)}\t of which {left_n[experiment][filename]} end on the left side and {right_n[experiment][filename]} on the right side, with ratios {(left_n[experiment][filename]/len(x_displacement_serie[experiment][filename]))*100}% left and {(right_n[experiment][filename]/len(x_displacement_serie[experiment][filename]))*100}% right{chr(10)}')

    if any(file.endswith('.xlsx') for file in files): # If folder contains any xlsx files do...
        max_min_cells[experiment]['max'] = max(numcells[experiment].values())
        max_min_cells[experiment]['min'] = min(numcells[experiment].values())
        logging.info(f'Max and min number of cells per rep in {experiment} are {max_min_cells[experiment]["min"]}-{max_min_cells[experiment]["max"]}')
        numreps[experiment] = len(files)
        logging.info(f'{experiment} contains {numreps[experiment]} videos')
        tracks_quantity[experiment] = sum(numcells[experiment].values())
        logging.info(f'{experiment} contains {tracks_quantity[experiment]} tracks')
        logging.info(f'Tracks in {experiment} displacement values:{chr(10)}{chr(10).join(str(v) for v in sum(x_displacement_serie[experiment].values(),[]))}')
        logging.info(f'{experiment} has {sum(right_n[experiment].values())} cells to the right')
        logging.info(f'{experiment} has {sum(left_n[experiment].values())} cells to the left')
        logging.info(f'{experiment} has {(sum(left_n[experiment].values())/tracks_quantity[experiment])*100} left side ratio')
        logging.info(f'{experiment} has {(sum(right_n[experiment].values())/tracks_quantity[experiment])*100} right side ratio')
    else:
        logging.info(f'\nThere are no xlsx files in folder: {root}')

logging.info(f'All subfolders contain {sum(numreps.values())} videos and {sum(tracks_quantity.values())} tracks')
elapsed = time.time() - t
logging.info(f'{elapsed} seconds elapsed')

# Count "leaf" folders (videos) in the supp. material directory

logging.info(f'{chr(10)}{chr(10)}Now counting videos in Supp. Material and xlsx files in \
"tracks válidas" folder...{chr(10)}{chr(10)}')
folders = []
supp_material = r'E:\Doctorado\Amebas\Papers enucleadas TODO\frames completos'
for root, dirs, files in os.walk(supp_material):
    for file in files:
        if file.endswith(".jpg"):
            folders.append(os.path.join(root, file))
            img = Image.open(os.path.join(root, file))
            wid, hgt = img.size
            if wid != 1280 or hgt!= 960:
                raise SystemExit(f'\t {root.rsplit({chr(92)},1)[1]} resolution not 1280x960')
            # logging.info(f'{chr(10)}File {root.split(chr(92),6)[-1]} has {str(wid) + "x" + str(hgt)} resolution')
            break
logging.info(f'There are {len(folders)} videos in TODOS enucleadas and {len(excelfiles)} xlsx files in "tracks válidas"{chr(10)}{chr(10)}')
# Out:
# [04-Nov-23 21:59:57]
#
#
# walk_dir = C:\Users\pc\Desktop\Doctorado\Publicaciones\Papers enucleadas\Tracks válidas
# [04-Nov-23 21:59:57] walk_dir (absolute) = C:\Users\pc\Desktop\Doctorado\Publicaciones\Papers enucleadas\Tracks válidas
# [04-Nov-23 21:59:57]
# NOW IN ROOT = C:\Users\pc\Desktop\Doctorado\Publicaciones\Papers enucleadas\Tracks válidas
#
# [04-Nov-23 21:59:57]
# There are 2 files in C:\Users\pc\Desktop\Doctorado\Publicaciones\Papers enucleadas\Tracks válidas
# [04-Nov-23 21:59:57] 	- subdirectory 1.No stimuli
# [04-Nov-23 21:59:57] 	- subdirectory 2.Galvanotaxis
# [04-Nov-23 21:59:57] 	- subdirectory 3.Chemotaxis
# [04-Nov-23 21:59:57] 	- subdirectory 4.Double stimulus
# [04-Nov-23 21:59:57] 	- subdirectory 5.Pavlovian test
# [04-Nov-23 21:59:57]
# There are no xlsx files in folder: C:\Users\pc\Desktop\Doctorado\Publicaciones\Papers enucleadas\Tracks válidas
# [04-Nov-23 21:59:57]
# NOW IN ROOT = C:\Users\pc\Desktop\Doctorado\Publicaciones\Papers enucleadas\Tracks válidas\1.No stimuli
#
# [04-Nov-23 21:59:57]
# There are 0 files in C:\Users\pc\Desktop\Doctorado\Publicaciones\Papers enucleadas\Tracks válidas\1.No stimuli
# [04-Nov-23 21:59:57] 	- subdirectory Cells
# [04-Nov-23 21:59:57] 	- subdirectory Cytoplasts
# [04-Nov-23 21:59:57]
# There are no xlsx files in folder: C:\Users\pc\Desktop\Doctorado\Publicaciones\Papers enucleadas\Tracks válidas\1.No stimuli
# [04-Nov-23 21:59:57]
# NOW IN ROOT = C:\Users\pc\Desktop\Doctorado\Publicaciones\Papers enucleadas\Tracks válidas\1.No stimuli\Cells
#
# [04-Nov-23 21:59:57]
# There are 17 files in C:\Users\pc\Desktop\Doctorado\Publicaciones\Papers enucleadas\Tracks válidas\1.No stimuli\Cells
# [04-Nov-23 22:00:02]
# - video 06.02.23 01.36.xlsx contains 4 tracks and 16400 data points,
#
# 	 of which 3 end on the left side and 1 on the right side, with ratios 75.0% left and 25.0% right
# [04-Nov-23 22:00:07]
# - video 06.02.23 02.19.xlsx contains 4 tracks and 16400 data points,
#
# 	 of which 3 end on the left side and 1 on the right side, with ratios 75.0% left and 25.0% right
# [04-Nov-23 22:00:12]
# - video 06.02.23 03.02.xlsx contains 4 tracks and 16400 data points,
#
# 	 of which 4 end on the left side and 0 on the right side, with ratios 100.0% left and 0.0% right
# [04-Nov-23 22
xlsx contains 1 tracks and 4100 data points,
#
# 	 of which 0 end on the left side and 1 on the right side, with ratios 0.0% left and 100.0% right
# [04-Nov-23 22:04:07] Max and min number of cells per rep in 2.Galvanotaxis_Cytoplasts are 1-4
# [04-Nov-23 22:04:07] 2.Galvanotaxis_Cytoplasts contains 30 videos
# [04-Nov-23 22:04:07] 2.Galvanotaxis_Cytoplasts contains 57 tracks
# [04-Nov-23 22:04:07] Tracks in 2.Galvanotaxis_Cytoplasts displacement values:
# 21.083000000000027
# 173.75
# 118.0
# 126.0
# 10.0
# 13.625
# 78.33300000000003
# 51.06299999999999
# 48.125
# 118.75
# 158.875
# 44.5
# 25.625
# 50.20800000000003
# 82.43700000000001
# 98.25000000000006
# 118.5
# 82.50000000000006
# 53.375
# 37.75
# 55.18700000000001
# 121.125
# 100.91599999999994
# 193.49999999999994
# 76.83399999999995
# 66.5
# 234.0
# 67.625
# 33.125
# 34.75
# 84.334
# 136.625
# 137.625
# 47.66699999999997
# 112.0
# 34.25
# 35.33299999999997
# 208.66700000000003
# 136.0
# 84.75
# 78.5
# 136.125
# 22.91700000000003
# 42.68700000000001
# 55.375
# 113.625
# 125.25
# 52.25
# 255.75
# 301.5
# 116.33299999999997
# 202.5
# 209.50000000000006
# 126.0
# 120.625
# 29.812000000000012
# 50.56299999999999
# [04-Nov-23 22:04:07] 2.Galvanotaxis_Cytoplasts has 57 cells to the right
# [04-Nov-23 22:04:07] 2.Galvanotaxis_Cytoplasts has 0 cells to the left
# [04-Nov-23 22:04:07] 2.Galvanotaxis_Cytoplasts has 0.0 left side ratio
# [04-Nov-23 22:04:07] 2.Galvanotaxis_Cytoplasts has 100.0 right side ratio
# [04-Nov-23 22:04:07]
# NOW IN ROOT = C:\Users\pc\Desktop\Doctorado\Publicaciones\Papers enucleadas\Tracks válidas\3.Chemotaxis
#
# [04-Nov-23 22:04:07]
# There are 0 files in C:\Users\pc\Desktop\Doctorado\Publicaciones\Papers enucleadas\Tracks válidas\3.Chemotaxis
# [04-Nov-23 22:04:07] 	- subdirectory Cells
# [04-Nov-23 22:04:07] 	- subdirectory Cytoplasts
# [04-Nov-23 22:04:07]
# There are no xlsx files in folder: C:\Users\pc\Desktop\Doctorado\Publicaciones\Papers enucleadas\Tracks válidas\3.Chemotaxis
# [04-Nov-23 22:04:07]
# NOW IN ROOT = C:\Users\pc\Desktop\Doctorado\Publicaciones\Papers enucleadas\Tracks válidas\3.Chemotaxis\Cells
#
# [04-Nov-23 22:04:07]
# There are 11 files in C:\Users\pc\Desktop\Doctorado\Publicaciones\Papers enucleadas\Tracks válidas\3.Chemotaxis\Cells
# [04-Nov-23 22:04:13]
# - video 05.02.23 16.35.xlsx contains 4 tracks and 16400 data points,
#
# 	 of which 3 end on the left side and 1 on the right side, with ratios 75.0% left and 25.0% right
# [04-Nov-23 22:04:19]
# - video 07.01.23 19.49.xlsx contains 4 tracks and 16400 data points,
#
# 	 of which 3 end on the left side and 1 on the right side, with ratios 75.0% left and 25.0% right
# [04-Nov-23 22:04:24]
# - video 08.01.23 17.22.xlsx contains 4 tracks and 16400 data points,
#
# 	 of which 3 end on the left side and 1 on the right side, with ratios 75.0% left and 25.0% right
# [04-Nov-23 22:04:29]
# - video 14.12.22 11.10.xlsx contains 4 tracks and 16400 data points,
#
# 	 of which 2 end on the left side and 2 on the right side, with ratios 50.0% left and 50.0% right
# [04-Nov-23 22:04:34]
# - video 14.12.22 12.46.xlsx contains 4 tracks and 16400 data points,
#
# 	 of which 4 end on the left side and 0 on the right side, with ratios 100.0% left and 0.0% right
# [04-Nov-23 22:04:39]
# - video 14.12.22 13.46.xlsx contains 4 tracks and 16400 data points,
#
# 	 of which 3 end on the left side and 1 on the right side, with ratios 75.0% left and 25.0% right
# [04-Nov-23 22:04:44]
# - video 14.12.22 17.04.xlsx contains 4 tracks and 16400 data points,
#
# 	 of which 3 end on the left side and 1 on the right side, with ratios 75.0% left and 25.0% right
# [04-Nov-23 22:04:49]
# - video 14.12.22 17.51.xlsx contains 4 tracks and 16400 data points,
#
# 	 of which 4 end on the left side and 0 on the right side, with ratios 100.0% left and 0.0% right
# [04-Nov-23 22:04:54]
# - video 14.12.22 19.36.xlsx contains 3 tracks and 12300 data points,
#
# 	 of which 2 end on the left side and 1 on the right side, with ratios 66.66666666666666% left and 33.33333333333333% right
# [04-Nov-23 22:04:59]
# - video 14.12.22 20.24.xlsx contains 4 tracks and 16400 data points,
#
# 	 of which 3 end on the left side and 1 on the right side, with ratios 75.0% left and 25.0% right
# [04-Nov-23 22:05:04]
# - video 14.12.22 21.17.xlsx contains 4 tracks and 16400 data points,
#
# 	 of which 4 end on the left side and 0 on the right side, with ratios 100.0% left and 0.0% right
# [04-Nov-23 22:05:04] Max and min number of cells per rep in 3.Chemotaxis_Cells are 3-4
# [04-Nov-23 22:05:04] 3.Chemotaxis_Cells contains 11 videos
# [04-Nov-23 22:05:04] 3.Chemotaxis_Cells contains 43 tracks
# [04-Nov-23 22:05:04] Tracks in 3.Chemotaxis_Cells displacement values:
# -47.0
# -32.0
# 3.125
# -31.75
# -43.83400000000006
# -62.83299999999997
# 40.5
# -44.5
# -77.0
# -24.25
# 151.0
# -91.0
# -60.0
# 155.25
# 15.25
# -67.58400000000006
# -70.91700000000003
# -70.41599999999994
# -90.0
# -125.75
# -152.0
# -142.5
# 53.0
# -223.75
# -22.0
# -142.66700000000003
# -48.875
# 70.125
# -136.83299999999997
# -109.0
# -74.66700000000003
# -93.75
# 35.5
# -87.83299999999997
# -139.5
# 56.25
# -121.625
# -215.75
# -75.5
# -213.75
# -217.75
# -206.0
# -130.5
# [04-Nov-23 22:05:04] 3.Chemotaxis_Cells has 9 cells to the right
# [04-Nov-23 22:05:04] 3.Chemotaxis_Cells has 34 cells to the left
# [04-Nov-23 22:05:04] 3.Chemotaxis_Cells has 79.06976744186046 left side ratio
# [04-Nov-23 22:05:04] 3.Chemotaxis_Cells has 20.930232558139537 right side ratio
# [04-Nov-23 22:05:04]
# NOW IN ROOT = C:\Users\pc\Desktop\Doctorado\Publicaciones\Papers enucleadas\Tracks válidas\3.Chemotaxis\Cytoplasts
#
# [04-Nov-23 22:05:04]
# There are 21 files in C:\Users\pc\Desktop\Doctorado\Publicaciones\Papers enucleadas\Tracks válidas\3.Chemotaxis\Cytoplasts
# [04-Nov-23 22:05:06]
# - video 03.01.23 16.06.xlsx contains 2 tracks and 6450 data points,
#
# 	 of which 2 end on the left side and 0 on the right side, with ratios 100.0% left and 0.0% right
# [04-Nov-23 22:05:08]
# - video 03.01.23 18.17.xlsx contains 1 tracks and 4100 data points,
#
# 	 of which 1 end on the left side and 0 on the right side, with ratios 100.0% left and 0.0% right
# [04-Nov-23 22:05:11]
# - video 03.01.23 19.12.xlsx contains 2 tracks and 10142 data points,
#
# 	 of which 0 end on the left side and 2 on the right side, with ratios 0.0% left and 100.0% right
# [04-Nov-23 22:05:15]
# - video 04.01.23 18.24.xlsx contains 3 tracks and 12300 data points,
#
# 	 of which 3 end on the left side and 0 on the right side, with ratios 100.0% left and 0.0% right
# [04-Nov-23 22:05:19]
# - video 04.01.23 21.00.xlsx contains 3 tracks and 12300 data points,
#
# 	 of which 1 end on the left side and 2 on the right side, with ratios 33.33333333333333% left and 66.66666666666666% right
# [04-Nov-23 22:05:21]
# - video 05.01.23 13.21.xlsx contains 1 tracks and 8200 data points,
#
# 	 of which 1 end on the left side and 0 on the right side, with ratios 100.0% left and 0.0% right
# [04-Nov-23 22:05:24]
# - video 05.01.23 15.36.xlsx contains 2 tracks and 10269 data points,
#
# 	 of which 1 end on the left side and 1 on the right side, with ratios 50.0% left and 50.0% right
# [04-Nov-23 22:05:28]
# - video 05.01.23 16.40.xlsx contains 3 tracks and 12300 data points,
#
# 	 of which 3 end on the left side and 0 on the right side, with ratios 100.0% left and 0.0% right
# [04-Nov-23 22:05:33]
# - video 05.01.23 20.45.xlsx contains 4 tracks and 16400 data points,
#
# 	 of which 3 end on the left side and 1 on the right side, with ratios 75.0% left and 25.0% right
# [04-Nov-23 22:05:37]
# - video 05.01.23 21.39.xlsx contains 3 tracks and 12300 data points,
#
# 	 of which 3 end on the left side and 0 on the right side, with ratios 100.0% left and 0.0% right
# [04-Nov-23 22:05:39]
# - video 05.02.23 14.18.xlsx contains 3 tracks and 7692 data points,
#
# 	 of which 3 end on the left side and 0 on the right side, with ratios 100.0% left and 0.0% right
# [04-Nov-23 22:05:44]
# - video 06.01.23 14.39.xlsx contains 4 tracks and 16400 data points,
#
# 	 of which 3 end on the left side and 1 on the right side, with ratios 75.0% left and 25.0% right
# [04-Nov-23 22:05:46]
# - video 06.01.23 15.39.xlsx contains 1 tracks and 4100 data points,
#
# 	 of which 1 end on the left side and 0 on the right side, with ratios 100.0% left and 0.0% right
# [04-Nov-23 22:05:47]
# - video 06.01.23 17.09.xlsx contains 1 tracks and 4100 data points,
#
# 	 of which 1 end on the left side and 0 on the right side, with ratios 100.0% left and 0.0% right
# [04-Nov-23 22:05:51]
# - video 06.01.23 20.47.xlsx contains 3 tracks and 12300 data points,
#
# 	 of which 3 end on the left side and 0 on the right side, with ratios 100.0% left and 0.0% right
# [04-Nov-23 22:05:53]
# - video 15.12.22 16.27.xlsx contains 2 tracks and 6075 data points,
#
# 	 of which 2 end on the left side and 0 on the right side, with ratios 100.0% left and 0.0% right
# [04-Nov-23 22:05:57]
# - video 15.12.22 17.28.xlsx contains 2 tracks and 10002 data points,
#
# 	 of which 0 end on the left side and 2 on the right side, with ratios 0.0% left and 100.0% right
# [04-Nov-23 22:05:59]
# - video 19.12.22 19.27.xlsx contains 2 tracks and 6296 data points,
#
# 	 of which 2 end on the left side and 0 on the right side, with ratios 100.0% left and 0.0% right
# [04-Nov-23 22:06:01]
# - video 20.12.22 14.48.xlsx contains 2 tracks and 8555 data points,
#
# 	 of which 2 end on the left side and 0 on the right side, with ratios 100.0% left and 0.0% right
# [04-Nov-23 22:06:03]
# - video 20.12.22 16.53.xlsx contains 2 tracks and 4975 data points,
#
# 	 of which 2 end on the left side and 0 on the right side, with ratios 100.0% left and 0.0% right
# [04-Nov-23 22:06:05]
# - video 20.12.22 21.16.xlsx contains 2 tracks and 5601 data points,
#
# 	 of which 1 end on the left side and 1 on the right side, with ratios 50.0% left and 50.0% right
# [04-Nov-23 22:06:05] Max and min number of cells per rep in 3.Chemotaxis_Cytoplasts are 1-4
# [04-Nov-23 22:06:05] 3.Chemotaxis_Cytoplasts contains 21 videos
# [04-Nov-23 22:06:05] 3.Chemotaxis_Cytoplasts contains 48 tracks
# [04-Nov-23 22:06:05] Tracks in 3.Chemotaxis_Cytoplasts displacement values:
# -110.0
# -32.16700000000003
# -112.0
# 73.5
# 37.16700000000003
# -247.75
# -10.5
# -49.5
# -38.125
# -22.91599999999994
# 60.0
# -38.0
# -42.16700000000003
# -56.0
# 29.83299999999997
# -30.718999999999937
# -46.79200000000003
# -115.875
# -146.0
# -38.43700000000001
# -112.625
# -93.33299999999997
# -24.0
# -208.33299999999997
# -106.0
# -147.625
# -109.5
# -155.83299999999997
# -183.0
# -225.33299999999997
# -270.0
# -55.36399999999992
# -219.375
# -221.5
# -314.0
# 100.25
# 158.0
# 152.875
# -47.5
# 54.41599999999994
# 52.66599999999994
# -82.125
# 83.5
# -69.5
# 25.25
# 88.37400000000002
# 57.83400000000006
# 109.33299999999997
# 178.16700000000003
# -51.5
# -134.875
# 43.375999999999976
# 43.16599999999994
# -33.33299999999997
# 54.75
# -62.25
# 45.0
# -18.41700000000003
# 56.75
# -23.375
# -32.625
# 43.5
# 0.83299999999997
# 114.0
# 8.375
# 113.375
# [04-Nov-23 22:07:37] 4.Double stimulus_Cells has 29 cells to the right
# [04-Nov-23 22:07:37] 4.Double stimulus_Cells has 44 cells to the left
# [04-Nov-23 22:07:37] 4.Double stimulus_Cells has 60.273972602739725 left side ratio
# [04-Nov-23 22:07:37] 4.Double stimulus_Cells has 39.726027397260275 right side ratio
# [04-Nov-23 22:07:37]
# NOW IN ROOT = C:\Users\pc\Desktop\Doctorado\Publicaciones\Papers enucleadas\Tracks válidas\4.Double stimulus\Cytoplasts
#
# [04-Nov-23 22:07:37]
# There are 15 files in C:\Users\pc\Desktop\Doctorado\Publicaciones\Papers enucleadas\Tracks válidas\4.Double stimulus\Cytoplasts
# [04-Nov-23 22:07:41]
# - video 09.01.23 17.29.xlsx contains 4 tracks and 10366 data points,
#
# 	 of which 3 end on the left side and 1 on the right side, with ratios 75.0% left and 25.0% right
# [04-Nov-23 22:07:45]
# - video 10.01.23 17.11.xlsx contains 4 tracks and 13823 data points,
#
# 	 of which 2 end on the left side and 2 on the right side, with ratios 50.0% left and 50.0% right
# [04-Nov-23 22:07:48]
# - video 12.01.23 19.10.xlsx contains 3 tracks and 8991 data points,
#
# 	 of which 1 end on the left side and 2 on the right side, with ratios 33.33333333333333% left and 66.66666666666666% right
# [04-Nov-23 22:07:52]
# - video 13.01.23 15.10.xlsx contains 4 tracks and 13455 data points,
#
# 	 of which 1 end on the left side and 3 on the right side, with ratios 25.0% left and 75.0% right
# [04-Nov-23 22:07:58]
# - video 16.01.23 16.44.xlsx contains 4 tracks and 16307 data points,
#
# 	 of which 2 end on the left side and 2 on the right side, with ratios 50.0% left and 50.0% right
# [04-Nov-23 22:08:02]
# - video 16.01.23 18.16.xlsx contains 3 tracks and 12300 data points,
#
# 	 of which 2 end on the left side and 1 on the right side, with ratios 66.66666666666666% left and 33.33333333333333% right
# [04-Nov-23 22:08:06]
# - video 17.01.23 13.58.xlsx contains 3 tracks and 12300 data points,
#
# 	 of which 1 end on the left side and 2 on the right side, with ratios 33.33333333333333% left and 66.66666666666666% right
# [04-Nov-23 22:08:10]
# - video 17.01.23 21.03.xlsx contains 4 tracks and 15602 data points,
#
# 	 of which 2 end on the left side and 2 on the right side, with ratios 50.0% left and 50.0% right
# [04-Nov-23 22:08:13]
# - video 18.01.23 13.40.xlsx contains 2 tracks and 7295 data points,
#
# 	 of which 1 end on the left side and 1 on the right side, with ratios 50.0% left and 50.0% right
# [04-Nov-23 22:08:16]
# - video 19.01.23 11.30.xlsx contains 3 tracks and 11070 data points,
#
# 	 of which 1 end on the left side and 2 on the right side, with ratios 33.33333333333333% left and 66.66666666666666% right
# [04-Nov-23 22:08:20]
# - video 19.01.23 13.41.xlsx contains 4 tracks and 12224 data points,
#
# 	 of which 3 end on the left side and 1 on the right side, with ratios 75.0% left and 25.0% right
# [04-Nov-23 22:08:25]
# - video 19.01.23 17.41.xlsx contains 4 tracks and 15800 data points,
#
# 	 of which 4 end on the left side and 0 on the right side, with ratios 100.0% left and 0.0% right
# [04-Nov-23 22:08:30]
# - video 19.01.23 20.16.xlsx contains 4 tracks and 16283 data points,
#
# 	 of which 4 end on the left side and 0 on the right side, with ratios 100.0% left and 0.0% right
# [04-Nov-23 22:08:33]
# - video 25.01.23 13.55.xlsx contains 3 tracks and 11589 data points,
#
# 	 of which 0 end on the left side and 3 on the right side, with ratios 0.0% left and 100.0% right
# [04-Nov-23 22:08:36]
# - video 26.01.23 11.04.xlsx contains 2 tracks and 7027 data points,
#
# 	 of which 2 end on the left side and 0 on the right side, with ratios 100.0% left and 0.0% right
# [04-Nov-23 22:08:36] Max and min number of cells per rep in 4.Double stimulus_Cytoplasts are 2-4
# [04-Nov-23 22:08:36] 4.Double stimulus_Cytoplasts contains 15 videos
# [04-Nov-23 22:08:36] 4.Double stimulus_Cytoplasts contains 51 tracks
# [04-Nov-23 22:08:36] Tracks in 4.Double stimulus_Cytoplasts displacement values:
# -78.91700000000003
# -36.66700000000003
# -225.75
# 29.41599999999994
# -193.33400000000006
# 180.08399999999995
# -159.5
# 67.0
# 95.66700000000003
# 93.5
# -149.5
# 161.5
# 43.83299999999997
# -80.75
# 63.5
# -73.75
# 76.16700000000003
# 71.5
# -112.58400000000006
# 51.33400000000006
# -108.33299999999997
# -49.75
# -78.625
# 14.625999999999976
# 111.06299999999999
# -37.875
# -200.75
# 3.08299999999997
# 8.437000000000012
# -10.83299999999997
# 133.875
# -19.687000000000012
# 12.25
# 25.25
# 16.5
# -82.75
# -125.0
# -245.83300000000003
# -187.58400000000006
# -41.90599999999995
# -41.5
# -155.33299999999997
# -251.83299999999997
# -181.94799999999998
# -26.0
# -89.0
# 37.25
# 13.0
# 15.916999999999916
# -38.25
# -109.25
# [04-Nov-23 22:08:36] 4.Double stimulus_Cytoplasts has 22 cells to the right
# [04-Nov-23 22:08:36] 4.Double stimulus_Cytoplasts has 29 cells to the left
# [04-Nov-23 22:08:36] 4.Double stimulus_Cytoplasts has 56.86274509803921 left side ratio
# [04-Nov-23 22:08:36] 4.Double stimulus_Cytoplasts has 43.13725490196079 right side ratio
# [04-Nov-23 22:08:36]
# NOW IN ROOT = C:\Users\pc\Desktop\Doctorado\Publicaciones\Papers enucleadas\Tracks válidas\5.Pavlovian test
#
# [04-Nov-23 22:08:36]
# There are 0 files in C:\Users\pc\Desktop\Doctorado\Publicaciones\Papers enucleadas\Tracks válidas\5.Pavlovian test
# [04-Nov-23 22:08:36] 	- subdirectory Cells
# [04-Nov-23 22:08:36] 	- subdirectory Cytoplasts
# [04-Nov-23 22:08:36]
# There are no xlsx files in folder: C:\Users\pc\Desktop\Doctorado\Publicaciones\Papers enucleadas\Tracks válidas\5.Pavlovian test
# [04-Nov-23 22:08:36]
# NOW IN ROOT = C:\Users\pc\Desktop\Doctorado\Publicaciones\Papers enucleadas\Tracks válidas\5.Pavlovian test\Cells
#
# [04-Nov-23 22:08:36]
# There are 0 files in C:\Users\pc\Desktop\Doctorado\Publicaciones\Papers enucleadas\Tracks válidas\5.Pavlovian test\Cells
# [04-Nov-23 22:08:36]
# There are no xlsx files in folder: C:\Users\pc\Desktop\Doctorado\Publicaciones\Papers enucleadas\Tracks válidas\5.Pavlovian test\Cells
# [04-Nov-23 22:08:36]
# NOW IN ROOT = C:\Users\pc\Desktop\Doctorado\Publicaciones\Papers enucleadas\Tracks válidas\5.Pavlovian test\Cytoplasts
#
# [04-Nov-23 22:08:36]
# There are 0 files in C:\Users\pc\Desktop\Doctorado\Publicaciones\Papers enucleadas\Tracks válidas\5.Pavlovian test\Cytoplasts
# [04-Nov-23 22:08:36]
# There are no xlsx files in folder: C:\Users\pc\Desktop\Doctorado\Publicaciones\Papers enucleadas\Tracks válidas\5.Pavlovian test\Cytoplasts
# [04-Nov-23 22:08:36] All subfolders contain 156 videos and 408 tracks
# [04-Nov-23 22:08:36] 519.0010540485382 seconds elapsed
# [04-Nov-23 22:08:36]
#
# Now counting videos in Supp. Material and xlsx files in "tracks válidas" folder...
#
#
# [04-Nov-23 22:08:37] There are 248 videos in TODOS enucleadas and 156 xlsx files in "tracks válidas"
