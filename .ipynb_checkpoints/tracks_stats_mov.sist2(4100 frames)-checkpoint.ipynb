# %%
# Count tracks & videos in excel files and supp. material
import os
from collections import defaultdict
from datetime import datetime
import time
import re
import sys
import pandas as pd
import logging
from PIL import Image

logging.basicConfig(
    level=logging.INFO,
    format="[%(asctime)s] %(message)s",
    datefmt='%d-%b-%y %H:%M:%S',
    handlers=[
        logging.FileHandler(fr'C:\Users\pc\Desktop\Doctorado\Publicaciones\Papers enucleadas\Tracks válidas\Track_info_{datetime.now().strftime("%d.%m.%Y_%H.%M.%S")}.txt'),
        logging.StreamHandler(sys.stdout)
    ]
)

t = time.time()

walk_dir = r'C:\Users\pc\Desktop\Doctorado\Publicaciones\Papers enucleadas\Tracks válidas'

logging.info('\n\n\nwalk_dir = ' + walk_dir)
# If your current working directory may change during script execution, it's recommended to
# immediately convert program arguments to an absolute path. Then the variable root below will
# be an absolute path as well.
walk_dir = os.path.abspath(walk_dir)
logging.info('walk_dir (absolute) = ' + os.path.abspath(walk_dir))

excelfiles = []
tracks_quantity = defaultdict()
numreps = defaultdict()
numcells = defaultdict(defaultdict().copy)
max_min_cells = defaultdict(defaultdict().copy)
left_n = defaultdict(defaultdict().copy)
right_n = defaultdict(defaultdict().copy)
x_displacement_serie = defaultdict(defaultdict().copy)

for root, subdirs, files in os.walk(walk_dir):
    logging.info(f'\nNOW IN ROOT = {root}\n')
    logging.info(f'\nThere are {len(files)} files in {root}')
    
    for subdir in subdirs:
        logging.info('\t- subdirectory ' + subdir)

    for filename in files:
        if filename.endswith('.xlsx'):
            excelfiles.append(filename)
            scenario = root.rsplit('\\',2)[1]
            cell_type = root.rsplit('\\',1)[1]
            experiment = scenario + '_' + cell_type
            file_path = os.path.join(root, filename)
            serie = pd.read_excel(file_path, header=None)
            #Coordenadas X iniciales de cada célula en esa serie
            o = serie.groupby(2, as_index=False).first()[4] 
            #Coordenadas X finales de cada célula en esa serie
            f = serie.groupby(2, as_index=False).last()[4]
            x_displacement_serie[experiment][filename] = [f_i-o_i for o_i,f_i in zip(o.tolist(), f.tolist())]
            if any(ele == 0 for ele in x_displacement_serie[experiment][filename]): # detect cells with no displacement
                logging.critical(f'\t- cell(s) nº {[idx for idx, val in enumerate(x_displacement_serie[experiment][filename]) if val == 0]} have no displacement')
                raise SystemExit(f'\t- cell(s) nº {[idx for idx, val in enumerate(x_displacement_serie[experiment][filename]) if val == 0]} have no displacement')
            left_n[experiment][filename] = sum(1 for value in x_displacement_serie[experiment][filename] if value < 0 )
            right_n[experiment][filename] = sum(1 for value in x_displacement_serie[experiment][filename] if value > 0 )
            numcells[experiment][filename] = len(x_displacement_serie[experiment][filename])
            logging.info(f'''\t- video {filename} contains {numcells[experiment][filename]} tracks, of which
            {left_n[experiment][filename]} end on the left side and {right_n[experiment][filename]} on the right side, with ratios {(left_n[experiment][filename]/len(x_displacement_serie[experiment][filename]))*100}% left and {(right_n[experiment][filename]/len(x_displacement_serie[experiment][filename]))*100}% right''')

    if any(file.endswith('.xlsx') for file in files): # If folder contains any xlsx files do...
        max_min_cells[experiment]['max'] = max(numcells[experiment].values())
        max_min_cells[experiment]['min'] = min(numcells[experiment].values())
        logging.info(f'Max and min number of cells per rep in {experiment} are {max_min_cells[experiment]["min"]}-{max_min_cells[experiment]["max"]}')
        numreps[experiment] = len(files)
        logging.info(f'{experiment} contains {numreps[experiment]} videos')
        tracks_quantity[experiment] = sum(numcells[experiment].values())
        logging.info(f'{experiment} contains {tracks_quantity[experiment]} tracks')
        logging.info(f'Tracks in {experiment} displacement values:{chr(10)}{chr(10).join(str(v) for v in sum(x_displacement_serie[experiment].values(),[]))}')
        logging.info(f'{experiment} has {sum(right_n[experiment].values())} cells to the right')
        logging.info(f'{experiment} has {sum(left_n[experiment].values())} cells to the left')
        logging.info(f'{experiment} has {(sum(left_n[experiment].values())/tracks_quantity[experiment])*100} left side ratio')
        logging.info(f'{experiment} has {(sum(right_n[experiment].values())/tracks_quantity[experiment])*100} right side ratio')
    else:
        logging.info(f'\nThere are no xlsx files in folder: {root}')

logging.info(f'''All subfolders contain {sum(numreps.values())} videos and {sum(tracks_quantity.values())} tracks''')
elapsed = time.time() - t
logging.info(f'{elapsed} seconds elapsed')

# Count "leaf" folders (videos) in the supp. material directory

logging.info(f'{chr(10)}{chr(10)}Now counting videos in Supp. Material and xlsx files in \
"tracks válidas" folder...{chr(10)}{chr(10)}')
folders = []
supp_material = r'E:\Doctorado\Amebas\Papers enucleadas TODO\frames completos'
for root, dirs, files in os.walk(supp_material):
    for file in files:
        if file.endswith(".jpg"):
            folders.append(os.path.join(root, file))
            img = Image.open(os.path.join(root, file))
            wid, hgt = img.size
            if wid != 1280 or hgt!= 960:
                raise SystemExit(f'\t {root.rsplit('\\',1)[1]} resolution not 1280x960')
            # logging.info(f'{chr(10)}File {root.split(chr(92),6)[-1]} has {str(wid) + "x" + str(hgt)} resolution')
            break
logging.info(f'There are {len(folders)} videos in TODOS enucleadas and {len(excelfiles)} xlsx files in "tracks válidas"{chr(10)}{chr(10)}')
# Out:
# [30-Oct-23 01:33:35]
#
#
# walk_dir = C:\Users\pc\Desktop\Doctorado\Publicaciones\Papers enucleadas\Tracks válidas
# [30-Oct-23 01:33:35] walk_dir (absolute) = C:\Users\pc\Desktop\Doctorado\Publicaciones\Papers enucleadas\Tracks válidas
# [30-Oct-23 01:33:35]
# NOW IN ROOT = C:\Users\pc\Desktop\Doctorado\Publicaciones\Papers enucleadas\Tracks válidas
#
# [30-Oct-23 01:33:35]
# There are 2 files in C:\Users\pc\Desktop\Doctorado\Publicaciones\Papers enucleadas\Tracks válidas
# [30-Oct-23 01:33:35] 	- subdirectory 1.No stimuli
# [30-Oct-23 01:33:35] 	- subdirectory 2.Galvanotaxis
# [30-Oct-23 01:33:35] 	- subdirectory 3.Chemotaxis
# [30-Oct-23 01:33:35] 	- subdirectory 4.Double stimulus
# [30-Oct-23 01:33:35] 	- subdirectory 5.Pavlovian test
# [30-Oct-23 01:33:35]
# There are no xlsx files in folder: C:\Users\pc\Desktop\Doctorado\Publicaciones\Papers enucleadas\Tracks válidas
# [30-Oct-23 01:33:35]
# NOW IN ROOT = C:\Users\pc\Desktop\Doctorado\Publicaciones\Papers enucleadas\Tracks válidas\1.No stimuli
#
# [30-Oct-23 01:33:35]
# There are 0 files in C:\Users\pc\Desktop\Doctorado\Publicaciones\Papers enucleadas\Tracks válidas\1.No stimuli
# [30-Oct-23 01:33:35] 	- subdirectory Cells
# [30-Oct-23 01:33:35] 	- subdirectory Cytoplasts
# [30-Oct-23 01:33:35]
# There are no xlsx files in folder: C:\Users\pc\Desktop\Doctorado\Publicaciones\Papers enucleadas\Tracks válidas\1.No stimuli
# [30-Oct-23 01:33:35]
# NOW IN ROOT = C:\Users\pc\Desktop\Doctorado\Publicaciones\Papers enucleadas\Tracks válidas\1.No stimuli\Cells
#
# [30-Oct-23 01:33:35]
# There are 17 files in C:\Users\pc\Desktop\Doctorado\Publicaciones\Papers enucleadas\Tracks válidas\1.No stimuli\Cells
# [30-Oct-23 01:33:40] 	- video 06.02.23 01.36.xlsx contains 4 tracks, of which
#             3 end on the left side and 1 on the right side, with ratios 75.0% left and 25.0% right
# [30-Oct-23 01:33:46] 	- video 06.02.23 02.19.xlsx contains 4 tracks, of which
#             3 end on the left side and 1 on the right side, with ratios 75.0% left and 25.0% right
# [30-Oct-23 01:33:51] 	- video 06.02.23 03.02.xlsx contains 4 tracks, of which
#             4 end on the left side and 0 on the right side, with ratios 100.0% left and 0.0% right
# [30-Oct-23 01:33:56] 	- video 14.11.22 15.45.xlsx contains 4 tracks, of which
#             2 end on the left side and 2 on the right side, with ratios 50.0% left and 50.0% right
# [30-Oct-23 01:34:01] 	- video 14.11.22 18.34.xlsx contains 4 tracks, of which
#             2 end on the left side and 2 on the right side, with ratios 50.0% left and 50.0% right
# [30-Oct-23 01
 end on the left side and 1 on the right side, with ratios 0.0% left and 100.0% right
# [30-Oct-23 01:37:42] Max and min number of cells per rep in 2.Galvanotaxis_Cytoplasts are 1-4
# [30-Oct-23 01:37:42] 2.Galvanotaxis_Cytoplasts contains 30 videos
# [30-Oct-23 01:37:42] 2.Galvanotaxis_Cytoplasts contains 57 tracks
# [30-Oct-23 01:37:42] Tracks in 2.Galvanotaxis_Cytoplasts displacement values:
# 21.083000000000027
# 173.75
# 118.0
# 126.0
# 10.0
# 13.625
# 78.33300000000003
# 51.06299999999999
# 48.125
# 118.75
# 158.875
# 44.5
# 25.625
# 50.20800000000003
# 82.43700000000001
# 98.25000000000006
# 118.5
# 82.50000000000006
# 53.375
# 37.75
# 55.18700000000001
# 121.125
# 100.91599999999994
# 193.49999999999994
# 76.83399999999995
# 66.5
# 234.0
# 67.625
# 33.125
# 34.75
# 84.334
# 136.625
# 137.625
# 47.66699999999997
# 112.0
# 34.25
# 35.33299999999997
# 208.66700000000003
# 136.0
# 84.75
# 78.5
# 136.125
# 22.91700000000003
# 42.68700000000001
# 55.375
# 113.625
# 125.25
# 52.25
# 255.75
# 301.5
# 116.33299999999997
# 202.5
# 209.50000000000006
# 126.0
# 120.625
# 29.812000000000012
# 50.56299999999999
# [30-Oct-23 01:37:42] 2.Galvanotaxis_Cytoplasts has 57 cells to the right
# [30-Oct-23 01:37:42] 2.Galvanotaxis_Cytoplasts has 0 cells to the left
# [30-Oct-23 01:37:42] 2.Galvanotaxis_Cytoplasts has 0.0 left side ratio
# [30-Oct-23 01:37:42] 2.Galvanotaxis_Cytoplasts has 100.0 right side ratio
# [30-Oct-23 01:37:42]
# NOW IN ROOT = C:\Users\pc\Desktop\Doctorado\Publicaciones\Papers enucleadas\Tracks válidas\3.Chemotaxis
#
# [30-Oct-23 01:37:42]
# There are 0 files in C:\Users\pc\Desktop\Doctorado\Publicaciones\Papers enucleadas\Tracks válidas\3.Chemotaxis
# [30-Oct-23 01:37:42] 	- subdirectory Cells
# [30-Oct-23 01:37:42] 	- subdirectory Cytoplasts
# [30-Oct-23 01:37:42]
# There are no xlsx files in folder: C:\Users\pc\Desktop\Doctorado\Publicaciones\Papers enucleadas\Tracks válidas\3.Chemotaxis
# [30-Oct-23 01:37:42]
# NOW IN ROOT = C:\Users\pc\Desktop\Doctorado\Publicaciones\Papers enucleadas\Tracks válidas\3.Chemotaxis\Cells
#
# [30-Oct-23 01:37:42]
# There are 11 files in C:\Users\pc\Desktop\Doctorado\Publicaciones\Papers enucleadas\Tracks válidas\3.Chemotaxis\Cells
# [30-Oct-23 01:37:47] 	- video 05.02.23 16.35.xlsx contains 4 tracks, of which
#             3 end on the left side and 1 on the right side, with ratios 75.0% left and 25.0% right
# [30-Oct-23 01:37:52] 	- video 07.01.23 19.49.xlsx contains 4 tracks, of which
#             3 end on the left side and 1 on the right side, with ratios 75.0% left and 25.0% right
# [30-Oct-23 01:37:58] 	- video 08.01.23 17.22.xlsx contains 4 tracks, of which
#             3 end on the left side and 1 on the right side, with ratios 75.0% left and 25.0% right
# [30-Oct-23 01:38:03] 	- video 14.12.22 11.10.xlsx contains 4 tracks, of which
#             2 end on the left side and 2 on the right side, with ratios 50.0% left and 50.0% right
# [30-Oct-23 01:38:07] 	- video 14.12.22 12.46.xlsx contains 4 tracks, of which
#             4 end on the left side and 0 on the right side, with ratios 100.0% left and 0.0% right
# [30-Oct-23 01:38:12] 	- video 14.12.22 13.46.xlsx contains 4 tracks, of which
#             3 end on the left side and 1 on the right side, with ratios 75.0% left and 25.0% right
# [30-Oct-23 01:38:17] 	- video 14.12.22 17.04.xlsx contains 4 tracks, of which
#             3 end on the left side and 1 on the right side, with ratios 75.0% left and 25.0% right
# [30-Oct-23 01:38:22] 	- video 14.12.22 17.51.xlsx contains 4 tracks, of which
#             4 end on the left side and 0 on the right side, with ratios 100.0% left and 0.0% right
# [30-Oct-23 01:38:26] 	- video 14.12.22 19.36.xlsx contains 3 tracks, of which
#             2 end on the left side and 1 on the right side, with ratios 66.66666666666666% left and 33.33333333333333% right
# [30-Oct-23 01:38:31] 	- video 14.12.22 20.24.xlsx contains 4 tracks, of which
#             3 end on the left side and 1 on the right side, with ratios 75.0% left and 25.0% right
# [30-Oct-23 01:38:35] 	- video 14.12.22 21.17.xlsx contains 4 tracks, of which
#             4 end on the left side and 0 on the right side, with ratios 100.0% left and 0.0% right
# [30-Oct-23 01:38:35] Max and min number of cells per rep in 3.Chemotaxis_Cells are 3-4
# [30-Oct-23 01:38:35] 3.Chemotaxis_Cells contains 11 videos
# [30-Oct-23 01:38:35] 3.Chemotaxis_Cells contains 43 tracks
# [30-Oct-23 01:38:35] Tracks in 3.Chemotaxis_Cells displacement values:
# -47.0
# -32.0
# 3.125
# -31.75
# -43.83400000000006
# -62.83299999999997
# 40.5
# -44.5
# -77.0
# -24.25
# 151.0
# -91.0
# -60.0
# 155.25
# 15.25
# -67.58400000000006
# -70.91700000000003
# -70.41599999999994
# -90.0
# -125.75
# -152.0
# -142.5
# 53.0
# -223.75
# -22.0
# -142.66700000000003
# -48.875
# 70.125
# -136.83299999999997
# -109.0
# -74.66700000000003
# -93.75
# 35.5
# -87.83299999999997
# -139.5
# 56.25
# -121.625
# -215.75
# -75.5
# -213.75
# -217.75
# -206.0
# -130.5
# [30-Oct-23 01:38:35] 3.Chemotaxis_Cells has 9 cells to the right
# [30-Oct-23 01:38:35] 3.Chemotaxis_Cells has 34 cells to the left
# [30-Oct-23 01:38:35] 3.Chemotaxis_Cells has 79.06976744186046 left side ratio
# [30-Oct-23 01:38:35] 3.Chemotaxis_Cells has 20.930232558139537 right side ratio
# [30-Oct-23 01:38:35]
# NOW IN ROOT = C:\Users\pc\Desktop\Doctorado\Publicaciones\Papers enucleadas\Tracks válidas\3.Chemotaxis\Cytoplasts
#
# [30-Oct-23 01:38:35]
# There are 21 files in C:\Users\pc\Desktop\Doctorado\Publicaciones\Papers enucleadas\Tracks válidas\3.Chemotaxis\Cytoplasts
# [30-Oct-23 01:38:37] 	- video 03.01.23 16.06.xlsx contains 2 tracks, of which
#             2 end on the left side and 0 on the right side, with ratios 100.0% left and 0.0% right
# [30-Oct-23 01:38:39] 	- video 03.01.23 18.17.xlsx contains 1 tracks, of which
#             1 end on the left side and 0 on the right side, with ratios 100.0% left and 0.0% right
# [30-Oct-23 01:38:42] 	- video 03.01.23 19.12.xlsx contains 2 tracks, of which
#             0 end on the left side and 2 on the right side, with ratios 0.0% left and 100.0% right
# [30-Oct-23 01:38:46] 	- video 04.01.23 18.24.xlsx contains 3 tracks, of which
#             3 end on the left side and 0 on the right side, with ratios 100.0% left and 0.0% right
# [30-Oct-23 01:38:49] 	- video 04.01.23 21.00.xlsx contains 3 tracks, of which
#             1 end on the left side and 2 on the right side, with ratios 33.33333333333333% left and 66.66666666666666% right
# [30-Oct-23 01:38:52] 	- video 05.01.23 13.21.xlsx contains 1 tracks, of which
#             1 end on the left side and 0 on the right side, with ratios 100.0% left and 0.0% right
# [30-Oct-23 01:38:55] 	- video 05.01.23 15.36.xlsx contains 2 tracks, of which
#             1 end on the left side and 1 on the right side, with ratios 50.0% left and 50.0% right
# [30-Oct-23 01:38:58] 	- video 05.01.23 16.40.xlsx contains 3 tracks, of which
#             3 end on the left side and 0 on the right side, with ratios 100.0% left and 0.0% right
# [30-Oct-23 01:39:03] 	- video 05.01.23 20.45.xlsx contains 4 tracks, of which
#             3 end on the left side and 1 on the right side, with ratios 75.0% left and 25.0% right
# [30-Oct-23 01:39:07] 	- video 05.01.23 21.39.xlsx contains 3 tracks, of which
#             3 end on the left side and 0 on the right side, with ratios 100.0% left and 0.0% right
# [30-Oct-23 01:39:09] 	- video 05.02.23 14.18.xlsx contains 3 tracks, of which
#             3 end on the left side and 0 on the right side, with ratios 100.0% left and 0.0% right
# [30-Oct-23 01:39:14] 	- video 06.01.23 14.39.xlsx contains 4 tracks, of which
#             3 end on the left side and 1 on the right side, with ratios 75.0% left and 25.0% right
# [30-Oct-23 01:39:15] 	- video 06.01.23 15.39.xlsx contains 1 tracks, of which
#             1 end on the left side and 0 on the right side, with ratios 100.0% left and 0.0% right
# [30-Oct-23 01:39:17] 	- video 06.01.23 17.09.xlsx contains 1 tracks, of which
#             1 end on the left side and 0 on the right side, with ratios 100.0% left and 0.0% right
# [30-Oct-23 01:39:20] 	- video 06.01.23 20.47.xlsx contains 3 tracks, of which
#             3 end on the left side and 0 on the right side, with ratios 100.0% left and 0.0% right
# [30-Oct-23 01:39:22] 	- video 15.12.22 16.27.xlsx contains 2 tracks, of which
#             2 end on the left side and 0 on the right side, with ratios 100.0% left and 0.0% right
# [30-Oct-23 01:39:25] 	- video 15.12.22 17.28.xlsx contains 2 tracks, of which
#             0 end on the left side and 2 on the right side, with ratios 0.0% left and 100.0% right
# [30-Oct-23 01:39:27] 	- video 19.12.22 19.27.xlsx contains 2 tracks, of which
#             2 end on the left side and 0 on the right side, with ratios 100.0% left and 0.0% right
# [30-Oct-23 01:39:30] 	- video 20.12.22 14.48.xlsx contains 2 tracks, of which
#             2 end on the left side and 0 on the right side, with ratios 100.0% left and 0.0% right
# [30-Oct-23 01:39:31] 	- video 20.12.22 16.53.xlsx contains 2 tracks, of which
#             2 end on the left side and 0 on the right side, with ratios 100.0% left and 0.0% right
# [30-Oct-23 01:39:33] 	- video 20.12.22 21.16.xlsx contains 2 tracks, of which
#             1 end on the left side and 1 on the right side, with ratios 50.0% left and 50.0% right
# [30-Oct-23 01:39:33] Max and min number of cells per rep in 3.Chemotaxis_Cytoplasts are 1-4
# [30-Oct-23 01:39:33] 3.Chemotaxis_Cytoplasts contains 21 videos
# [30-Oct-23 01:39:33] 3.Chemotaxis_Cytoplasts contains 48 tracks
# [30-Oct-23 01:39:33] Tracks in 3.Chemotaxis_Cytoplasts displacement values:
# -110.0
# -32.16700000000003
# -112.0
# 73.5
# 37.16700000000003
# -247.75
# -10.5
# -49.5
# 72.0
# 8.25
# -36.79200000000003
# -116.54099999999994
# 81.125
# -24.0
# -65.0
# -242.25
# -95.16700000000003
# 2.33299999999997
# -112.21900000000005
# -45.125
# -60.91700000000003
# -59.0
# -6.125
# -22.33400000000006
# -4.041999999999916
# -33.25
# -59.68799999999999
# 90.83400000000006
# -67.25
# -120.5
# -49.75
# -66.5
# -83.875
# -19.625
# -83.33299999999997
comp has 1280x960 resolution
# [30-Oct-23 01:41:06]
# File 15.01.23 13.38 comp has 1280x960 resolution
# [30-Oct-23 01:41:06]
# File 15.01.23 17.56 comp has 1280x960 resolution
# [30-Oct-23 01:41:07]
# File 15.01.23 19.49 comp has 1280x960 resolution
# [30-Oct-23 01:41:07]
# File 16.01.23 16.44 comp has 1280x960 resolution
# [30-Oct-23 01:41:07]
# File 16.01.23 18.16 comp has 1280x960 resolution
# [30-Oct-23 01:41:07]
# File 17.01.23 13.58 comp has 1280x960 resolution
# [30-Oct-23 01:41:07]
# File 17.01.23 16.13 comp has 1280x960 resolution
# [30-Oct-23 01:41:07]
# File 17.01.23 21.03 comp has 1280x960 resolution
# [30-Oct-23 01:41:07]
# File 18.01.23 13.40 comp has 1280x960 resolution
# [30-Oct-23 01:41:07]
# File 18.01.23 18.30 comp has 1280x960 resolution
# [30-Oct-23 01:41:07]
# File 18.01.23 20.37 comp has 1280x960 resolution
# [30-Oct-23 01:41:08]
# File 19.01.23 11.30 comp has 1280x960 resolution
# [30-Oct-23 01:41:08]
# File 19.01.23 13.41 comp has 1280x960 resolution
# [30-Oct-23 01:41:08]
# File 19.01.23 17.41 comp has 1280x960 resolution
# [30-Oct-23 01:41:08]
# File 19.01.23 20.16 comp has 1280x960 resolution
# [30-Oct-23 01:41:08]
# File 20.01.23 12.56 comp con nucleo ha muerto una en manipulacion has 1280x960 resolution
# [30-Oct-23 01:41:08]
# File 20.01.23 14.26 comp con nucleo has 1280x960 resolution
# [30-Oct-23 01:41:08]
# File 20.01.23 16.30 comp con nucleo has 1280x960 resolution
# [30-Oct-23 01:41:08]
# File 20.01.23 18.48 comp con nucleo has 1280x960 resolution
# [30-Oct-23 01:41:09]
# File 21.01.23 15.48 comp con nucleo has 1280x960 resolution
# [30-Oct-23 01:41:09]
# File 21.01.23 17.51 comp con nucleo has 1280x960 resolution
# [30-Oct-23 01:41:09]
# File 21.01.23 19.42 comp con nucleo has 1280x960 resolution
# [30-Oct-23 01:41:09]
# File 21.01.23 21.08 comp con nucleo has 1280x960 resolution
# [30-Oct-23 01:41:09]
# File 22.01.23 15.36 comp con nucleo has 1280x960 resolution
# [30-Oct-23 01:41:09]
# File 22.01.23 17.26 comp con nucleo has 1280x960 resolution
# [30-Oct-23 01:41:09]
# File 22.01.23 18.51 comp con nucleo has 1280x960 resolution
# [30-Oct-23 01:41:10]
# File 22.01.23 20.18 comp con nucleo has 1280x960 resolution
# [30-Oct-23 01:41:10]
# File 23.01.23 11.56 comp con nucleo has 1280x960 resolution
# [30-Oct-23 01:41:10]
# File 23.01.23 16.30 comp con nucleo has 1280x960 resolution
# [30-Oct-23 01:41:10]
# File 23.01.23 19.16 comp con nucleo has 1280x960 resolution
# [30-Oct-23 01:41:10]
# File 23.01.23 20.42 comp con nucleo has 1280x960 resolution
# [30-Oct-23 01:41:10]
# File 24.01.23 13.33 comp con nucleo has 1280x960 resolution
# [30-Oct-23 01:41:10]
# File 24.01.23 17.55 comp con nucleo has 1280x960 resolution
# [30-Oct-23 01:41:10]
# File 24.01.23 19.24 comp con nucleo has 1280x960 resolution
# [30-Oct-23 01:41:10]
# File 24.01.23 20.50 comp con nucleo has 1280x960 resolution
# [30-Oct-23 01:41:11]
# File 25.01.23 13.55 comp has 1280x960 resolution
# [30-Oct-23 01:41:11]
# File 26.01.23 11.04 comp has 1280x960 resolution
# [30-Oct-23 01:41:11]
# File 26.01.23 12.35 comp has 1280x960 resolution
# [30-Oct-23 01:41:11]
# File 28.01.23 20.01 comp has 1280x960 resolution
# [30-Oct-23 01:41:11]
# File 01.12.22 15.47 has 1280x960 resolution
# [30-Oct-23 01:41:11]
# File 02.12.22 14.34 has 1280x960 resolution
# [30-Oct-23 01:41:11]
# File 02.12.22 16.18 has 1280x960 resolution
# [30-Oct-23 01:41:11]
# File 03.01.23 14.05 con nucleo has 1280x960 resolution
# [30-Oct-23 01:41:11]
# File 05.02.23 18.54 has 1280x960 resolution
# [30-Oct-23 01:41:11]
# File 05.02.23 20.38 con nucleo has 1280x960 resolution
# [30-Oct-23 01:41:11]
# File 05.02.23 21.46 con nucleo has 1280x960 resolution
# [30-Oct-23 01:41:11]
# File 05.12.22 10.00 has 1280x960 resolution
# [30-Oct-23 01:41:11]
# File 05.12.22 11.12 has 1280x960 resolution
# [30-Oct-23 01:41:11]
# File 05.12.22 14.25 has 1280x960 resolution
# [30-Oct-23 01:41:11]
# File 05.12.22 16.12 has 1280x960 resolution
# [30-Oct-23 01:41:11]
# File 05.12.22 17.58 has 1280x960 resolution
# [30-Oct-23 01:41:11]
# File 06.12.22 17.40 has 1280x960 resolution
# [30-Oct-23 01:41:11]
# File 06.12.22 19.14 has 1280x960 resolution
# [30-Oct-23 01:41:11]
# File 06.12.22 21.07 has 1280x960 resolution
# [30-Oct-23 01:41:11]
# File 07.12.22 12.47 has 1280x960 resolution
# [30-Oct-23 01:41:12]
# File 07.12.22 13.58 has 1280x960 resolution
# [30-Oct-23 01:41:12]
# File 07.12.22 15.18 has 1280x960 resolution
# [30-Oct-23 01:41:12]
# File 07.12.22 17.27 has 1280x960 resolution
# [30-Oct-23 01:41:12]
# File 28.11.22 13.04 con nucleo has 1280x960 resolution
# [30-Oct-23 01:41:12]
# File 28.11.22 16.50 con nucleo has 1280x960 resolution
# [30-Oct-23 01:41:12]
# File 28.11.22 17.50 con nucleo has 1280x960 resolution
# [30-Oct-23 01:41:12]
# File 28.11.22 19.30 con nucleo has 1280x960 resolution
# [30-Oct-23 01:41:12]
# File 28.11.22 20.36 con nucleo has 1280x960 resolution
# [30-Oct-23 01:41:12]
# File 29.01.23 20.28 has 1280x960 resolution
# [30-Oct-23 01:41:12]
# File 29.01.23 21.39 dos enucleadas has 1280x960 resolution
# [30-Oct-23 01:41:12]
# File 29.11.22 11.41 con nucleo has 1280x960 resolution
# [30-Oct-23 01:41:12]
# File 29.11.22 13.04 has 1280x960 resolution
# [30-Oct-23 01:41:12]
# File 29.11.22 19.13 has 1280x960 resolution
# [30-Oct-23 01:41:12]
# File 29.11.22 20.27 has 1280x960 resolution
# [30-Oct-23 01:41:12]
# File 30.01.23 00.34 has 1280x960 resolution
# [30-Oct-23 01:41:12]
# File 30.01.23 03.06 has 1280x960 resolution
# [30-Oct-23 01:41:12]
# File 30.01.23 04.39 has 1280x960 resolution
# [30-Oct-23 01:41:12]
# File 30.01.23 05.45 has 1280x960 resolution
# [30-Oct-23 01:41:12]
# File 30.11.22 12.35 has 1280x960 resolution
# [30-Oct-23 01:41:12]
# File 30.11.22 15.51 has 1280x960 resolution
# [30-Oct-23 01:41:12]
# File 30.11.22 18.00 has 1280x960 resolution
# [30-Oct-23 01:41:12]
# File 30.11.22 19.14 has 1280x960 resolution
# [30-Oct-23 01:41:12]
# File 30.11.22 20.09 has 1280x960 resolution
# [30-Oct-23 01:41:12]
# File 01.02.23 16.56 ind con nucleo has 1280x960 resolution
# [30-Oct-23 01:41:13]
# File 01.02.23 19.12 ind con nucleo has 1280x960 resolution
# [30-Oct-23 01:41:13]
# File 01.02.23 20.35 ind con nucleo has 1280x960 resolution
# [30-Oct-23 01:41:13]
# File 02.02.23 12.45 ind con nucleo has 1280x960 resolution
# [30-Oct-23 01:41:14]
# File 02.02.23 15.32 ind con nucleo has 1280x960 resolution
# [30-Oct-23 01:41:14]
# File 03.02.23 17.23 ind con nucleo has 1280x960 resolution
# [30-Oct-23 01:41:15]
# File 04.02.23 14.39 ind con nucleo has 1280x960 resolution
# [30-Oct-23 01:41:16]
# File 04.02.23 16.13 ind con nucleo has 1280x960 resolution
# [30-Oct-23 01:41:16]
# File 04.02.23 18.50 ind has 1280x960 resolution
# [30-Oct-23 01:41:16]
# File 04.02.23 20.40 ind has 1280x960 resolution
# [30-Oct-23 01:41:16]
# File 09.01.23 17.29 ind has 1280x960 resolution
# [30-Oct-23 01:41:16]
# File 10.01.23 11.47 ind has 1280x960 resolution
# [30-Oct-23 01:41:16]
# File 10.01.23 15.42 ind has 1280x960 resolution
# [30-Oct-23 01:41:17]
# File 10.01.23 17.11 ind has 1280x960 resolution
# [30-Oct-23 01:41:17]
# File 10.01.23 19.12 ind has 1280x960 resolution
# [30-Oct-23 01:41:17]
# File 11.01.23 12.23 ind has 1280x960 resolution
# [30-Oct-23 01:41:17]
# File 11.01.23 18.54 ind has 1280x960 resolution
# [30-Oct-23 01:41:17]
# File 12.01.23 13.43 ind has 1280x960 resolution
# [30-Oct-23 01:41:17]
# File 12.01.23 19.10 ind has 1280x960 resolution
# [30-Oct-23 01:41:17]
# File 13.01.23 13.22 ind has 1280x960 resolution
# [30-Oct-23 01:41:17]
# File 13.01.23 15.10 ind has 1280x960 resolution
# [30-Oct-23 01:41:17]
# File 14.01.23 17.37 ind has 1280x960 resolution
# [30-Oct-23 01:41:17]
# File 14.01.23 19.07 ind has 1280x960 resolution
# [30-Oct-23 01:41:18]
# File 14.01.23 20.40 ind has 1280x960 resolution
# [30-Oct-23 01:41:18]
# File 15.01.23 13.38 ind has 1280x960 resolution
# [30-Oct-23 01:41:18]
# File 15.01.23 17.56 ind has 1280x960 resolution
# [30-Oct-23 01:41:18]
# File 15.01.23 19.49 ind has 1280x960 resolution
# [30-Oct-23 01:41:18]
# File 16.01.23 16.44 ind has 1280x960 resolution
# [30-Oct-23 01:41:18]
# File 16.01.23 18.16 ind has 1280x960 resolution
# [30-Oct-23 01:41:18]
# File 17.01.23 13.58 ind has 1280x960 resolution
# [30-Oct-23 01:41:18]
# File 17.01.23 16.13 ind has 1280x960 resolution
# [30-Oct-23 01:41:19]
# File 17.01.23 21.03 ind has 1280x960 resolution
# [30-Oct-23 01:41:19]
# File 18.01.23 13.40 ind has 1280x960 resolution
# [30-Oct-23 01:41:19]
# File 18.01.23 18.30 ind has 1280x960 resolution
# [30-Oct-23 01:41:19]
# File 18.01.23 20.37 ind has 1280x960 resolution
# [30-Oct-23 01:41:19]
# File 19.01.23 11.30 ind has 1280x960 resolution
# [30-Oct-23 01:41:19]
# File 19.01.23 13.41 ind has 1280x960 resolution
# [30-Oct-23 01:41:19]
# File 19.01.23 17.41 ind has 1280x960 resolution
# [30-Oct-23 01:41:19]
# File 19.01.23 20.16 ind has 1280x960 resolution
# [30-Oct-23 01:41:19]
# File 20.01.23 12.56 ind con nucleo has 1280x960 resolution
# [30-Oct-23 01:41:20]
# File 20.01.23 14.26 ind con nucleo has 1280x960 resolution
# [30-Oct-23 01:41:20]
# File 20.01.23 16.30 ind con nucleo has 1280x960 resolution
# [30-Oct-23 01:41:20]
# File 20.01.23 18.48 ind con nucleo has 1280x960 resolution
# [30-Oct-23 01:41:20]
# File 21.01.23 15.48 ind con nucleo has 1280x960 resolution
# [30-Oct-23 01:41:20]
# File 21.01.23 17.51 ind con nucleo has 1280x960 resolution
# [30-Oct-23 01:41:20]
# File 21.01.23 19.42 ind con nucleo has 1280x960 resolution
# [30-Oct-23 01:41:20]
# File 21.01.23 21.08 ind con nucleo has 1280x960 resolution
# [30-Oct-23 01:41:20]
# File 22.01.23 15.36 ind con nucleo has 1280x960 resolution
# [30-Oct-23 01:41:21]
# File 22.01.23 17.26 ind con nucleo has 1280x960 resolution
# [30-Oct-23 01:41:22]
# File 22.01.23 18.51 ind con nucleo has 1280x960 resolution
# [30-Oct-23 01:41:22]
# File 22.01.23 20.18 ind con nucleo has 1280x960 resolution
# [30-Oct-23 01:41:23]
# File 23.01.23 11.56 ind con nucleo has 1280x960 resolution
# [30-Oct-23 01:41:23]
# File 23.01.23 16.30 ind con nucleo has 1280x960 resolution
# [30-Oct-23 01:41:24]
# File 23.01.23 19.16 ind con nucleo has 1280x960 resolution
# [30-Oct-23 01:41:24]
# File 23.01.23 20.42 ind con nucleo has 1280x960 resolution
# [30-Oct-23 01:41